# %%
from IPython.display import YouTubeVideo
YouTubeVideo('ysdU4mnRYdM')

# %%
import numpy as np
import matplotlib.pyplot as plt
def f（t）
    return np.exp(-t)*np.cos(2*np*t)
t1=np.arange(0.0,5.0,0.1)
t2=np.arange(0.0,5.0,0.02)

plt.figure(1)
plt.subplot(211)
plt.plot(t1, f(t1), 'bo', t2, f(t2), 'k')

plt.subplot(212)
plt.plot(t2, np.cos(2*np.pi*t2), 'r--')
plt.show()
# Out:
#   File "<ipython-input-2-8df4c6cdda50>", line 3
#     def f（t）
#            ^
# SyntaxError: invalid character in identifier

# %%
import numpy as np
import matplotlib.pyplot as plt

mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, normed=1, facecolor='g', alpha=0.75)


plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()
# Out:
# /home/gil/anaconda3/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')
# /home/gil/anaconda3/lib/python3.5/site-packages/matplotlib/font_manager.py:273: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   warnings.warn('Matplotlib is building the font cache using fc-list. This may take a moment.')

# %%
t=plt.xlabel('my data', fontsize=14, color='red')

# %%
# %run phugoid.py
matplotlib inline
# Out:
#   File "<ipython-input-5-35310ca6f843>", line 2
#     matplotlib inline
#                     ^
# SyntaxError: invalid syntax

# %%
# %run phugoid.py
# %matplotlib inline

# %%
#zt=64, z=16, theta=0
plot_flight_path(64,16,0)

# %%
16/64
# Out:
# 0.25

# %%
plot_flight_path(64,16,numpy.pi)

# %%
plot_flight_path(16,48,0.)

# %%
plot_flight_path(64,16,-numpy.pi/2)
