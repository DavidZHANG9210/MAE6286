# %%
import numpy
from math import sin
p=7.0
r=numpy.array([11.2, 4.7, 6.6])
for i in r:
    print(sin(p/i)**3)
# Out:
# 0.20030150930292323
# 0.9900910096418035
# 0.6645423764180455

# %%
numpy.sin(p/r)
# Out:
# array([ 0.58509727,  0.99668603,  0.87265161])

# %%
theta_set = numpy.linspace(0, 0.5*numpy.pi, 10)
v_set = numpy.linspace(0, 10 , 10)

# %%
# original code
euler_step(v, theta)

# %%
# parametric study
for theta in theta_set:
    for v in v_set:
        euler_step(v, theta)
# Out:
# 0.0 0.0
# 1.11111111111 0.0
# 2.22222222222 0.0
# 3.33333333333 0.0
# 4.44444444444 0.0
# 5.55555555556 0.0
# 6.66666666667 0.0
# 7.77777777778 0.0
# 8.88888888889 0.0
# 10.0 0.0
# 0.0 0.174532925199
# 1.11111111111 0.174532925199
# 2.22222222222 0.174532925199
# 3.33333333333 0.174532925199
# 4.44444444444 0.174532925199
# 5.55555555556 0.174532925199
# 6.66666666667 0.174532925199
# 7.77777777778 0.174532925199
# 8.88888888889 0.174532925199
# 10.0 0.174532925199
# 0.0 0.349065850399
# 1.11111111111 0.349065850399
# 2.22222222222 0.349065850399
# 3.33333333333 0.349065850399
# 4.44444444444 0.349065850399
# 5.55555555556 0.349065850399
# 6.66666666667 0.349065850399
# 7.77777777778 0.349065850399
# 8.88888888889 0.349065850399
# 10.0 0.349065850399
# 0.0 0.523598775598
# 1.11111111111 0.523598775598
# 2.22222222222 0.523598775598
# 3.33333333333 0.523598775598
# 4.44444444444 0.523598775598
# 5.55555555556 0.523598775598
# 6.66666666667 0.523598775598
# ...

# %%
euler_solver(scaler, scaler)
